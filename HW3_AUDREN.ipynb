# %% [markdown]
# # Test data import and repositories loading

# %%
# !git clone https://github.com/44Ap0pt0se54/U_NET_medical_segmentation.git
from U_NET_medical_segmentation import UNET

# %%
# !gdown 1fu4bJA5bn6q_OETgHjqM0jPiG3TelA79
# !gdown 1WrMZLYh4QhXhQJwKkAhCjmkUyRFlTf_R

# !gdown 1OGIkPyv8_dsHegtnOJCyaaPa8l9mlrf0

# %% [markdown]
# # Performances of loaded model on test data

# %%
MyModel = UNET.Model()

# %%
MyModel.test_model()
